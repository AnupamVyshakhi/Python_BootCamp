# %%
a="Anupam\"s"
print(a)
# Out:
# Anupam"s

# %%
b="\"Maths\" is an 'excellent' subject"
print(b)
# Out:
# "Maths" is an 'excellent' subject

# %%
print(type(a))
print(len(b))
# Out:
# <class 'str'>
# 33

# %%
str='Uganda'
print(str[3])
st="I'm Spider-Man"
print(st[3:])
print(st[:])
print(a[::-1])
# Out:
# n
#  Spider-Man
# I'm Spider-Man
# s"mapunA

# %%
ap="APPLE"
print(ap.replace('P','Z'))
print(ap)
print(list(ap))
print("".join(ap))
print(ap*2)
print("Anupam"+" "+"Vyshakhi"+""+".S")
# Out:
# AZZLE
# APPLE
# ['A', 'P', 'P', 'L', 'E']
# APPLE
# APPLEAPPLE
# Anupam Vyshakhi.S

# %%
# string formatting techniques
# using %
name="John"
age=20
print("My name is %s and my age is %d"%(name,age))
# Out:
# My name is John and my age is 20

# %%
# using format
print("My name is {} and my age is {}".format(name,age))
# Out:
# My name is John and mu age is 20

# %%
# using f string
print(f"My name is {name} and my age is {age}")
# Out:
# My name is John and my age is 20

# %%
s="Hel\blo"
print(s)
string="zebra\a" # a beep sound
# Out:
# lo

# %%
an="I'm\fAnupam"
print(an)
# Out:
# I'mAnupam

# %%
# octal notation
z="\101"
print(z)
# Out:
# A

# %%
# hexadecimal
x="\x41"
print(x)
# Out:
# A

# %%
y=r"hello \n world"
print(y)
# Out:
# hello \n world

# %%
'''
capitalize()
casefold()
lower()
swapcase()
upper()
title()
lstrip()
rstrip()
strip()
split()
isalpha()
isalnum()
isdigit()
islower()
isupper()
isascii()
istitle() boolean methods
count(sub,beg,end)
find(sub,beg,end) true return index else return -1
index(sub,beg,end)
rfind(sub,beg,end) from back
rindex(sub,beg,end) from back '''
